# %% [markdown]
# ## Importing required libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.preprocessing import LabelEncoder
import seaborn as sb

# %%
df = pd.read_csv('100 Sales Records.csv')

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
usold = df.sort_values(ascending=False,by=['Units Sold'])
usold
# Out:
#                           Region         Country      Item Type Sales Channel  \
# 0          Australia and Oceania          Tuvalu      Baby Food       Offline
# 56         Australia and Oceania            Fiji        Clothes       Offline
# 74  Middle East and North Africa        Pakistan      Cosmetics       Offline
# 79         Australia and Oceania          Samoa       Cosmetics        Online
# 51            Sub-Saharan Africa         Lesotho         Fruits        Online
# ..                           ...             ...            ...           ...
# 88  Middle East and North Africa          Kuwait         Fruits        Online
# 58                        Europe  United Kingdom      Household        Online
# 47                        Europe     Switzerland  Personal Care        Online
# 43                        Europe        Slovakia     Vegetables        Online
# 10                          Asia      Kyrgyzstan     Vegetables        Online
#
# ...

# %%
#d = datetime.strptime(str, '%m-%d-%Y')
#d.strftime("%d/%m/%Y")

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'],format='%Y-%m-%d')
df['Year'] = pd.DatetimeIndex(df['Order Date']).year
df['Year']
# Out:
# 0     2010
# 1     2012
# 2     2014
# 3     2014
# 4     2013
#       ...
# 95    2011
# 96    2011
# 97    2016
# 98    2015
# 99    2012
# Name: Year, Length: 100, dtype: int64

# %%
df['Month'] = pd.DatetimeIndex(df['Order Date']).month
df['Month']
# Out:
# 0      5
# 1      8
# 2      5
# 3      6
# 4      2
#       ..
# 95     7
# 96    11
# 97     6
# 98     7
# 99     2
# Name: Month, Length: 100, dtype: int64

# %%
df.groupby('Item Type').sum()
# Out:
#                    Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Item Type
# Baby Food        4649561463       40545     1786.96    1115.94    10350327.60
# Beverages        3488436455       56708      379.60     254.32     2690794.60
# Cereal           5327696855       25877     1439.90     819.77     5322898.90
# Clothes          7557276802       71260     1420.64     465.92     7787292.80
# Cosmetics        6463416606       83718     5683.60    3423.29    36601509.60
# Fruits           5419570846       49998       93.30      69.20      466481.34
# Household        4984468632       44727     6014.43    4522.86    29889712.29
# Meat             1147372316       10675      843.78     729.38     4503675.75
# Office Supplies  4256053154       46967     7814.52    6299.52    30585380.07
# Personal Care    5742522973       48708      817.30     566.70     3980904.84
# Snacks           1674348985       13637      457.74     292.32     2080733.46
# ...

# %%
year_rev =  df.groupby('Year').sum()['Total Revenue'].reset_index()
year_rev
# Out:
#    Year  Total Revenue
# 0  2010    19186024.92
# 1  2011    11129166.07
# 2  2012    31898644.52
# 3  2013    20330448.66
# 4  2014    16630214.43
# 5  2015    12427982.86
# 6  2016    12372867.22
# 7  2017    13373419.63

# %%
plt.figure(figsize=(20,5))
plt.bar(year_rev['Year'],year_rev['Total Revenue'],color='maroon')
plt.xticks(year_rev['Year'])
plt.ylabel('Revenue in Crores')
plt.xlabel('Year')
plt.show()

# %%
month_rev =  df.groupby('Month').sum()['Total Revenue'].reset_index()
month_rev
# Out:
#     Month  Total Revenue
# 0       1    10482467.12
# 1       2    24740517.77
# 2       3     2274823.87
# 3       4    16187186.33
# 4       5    13215739.99
# 5       6     5230325.77
# 6       7    15669518.50
# 7       8     1128164.91
# 8       9     5314762.56
# 9      10    15287576.61
# 10     11    20568222.76
# 11     12     7249462.12

# %%
plt.figure(figsize=(20,5))
plt.plot(month_rev['Month'],month_rev['Total Revenue'],color='maroon')
plt.xticks(month_rev['Month'])
plt.ylabel('Revenue in Crores')
plt.xlabel('Month')
plt.show()

# %%
unit_rev =  df.groupby('Item Type').sum()['Units Sold'].reset_index()
unit_rev
# Out:
#           Item Type  Units Sold
# 0         Baby Food       40545
# 1         Beverages       56708
# 2            Cereal       25877
# 3           Clothes       71260
# 4         Cosmetics       83718
# 5            Fruits       49998
# 6         Household       44727
# 7              Meat       10675
# 8   Office Supplies       46967
# 9     Personal Care       48708
# 10           Snacks       13637
# 11       Vegetables       20051

# %%
plt.figure(figsize=(30,10))
plt.pie(unit_rev['Units Sold'],labels = unit_rev['Item Type'], autopct ='%0.1f%%', pctdistance = 0.8)
plt.axis("equal")
plt.show()

# %%
region_rev =  df.groupby('Region').sum()['Units Sold'].reset_index()
region_rev
# Out:
#                               Region  Units Sold
# 0                               Asia       59967
# 1              Australia and Oceania       68325
# 2  Central America and the Caribbean       35771
# 3                             Europe       98117
# 4       Middle East and North Africa       48678
# 5                      North America       19143
# 6                 Sub-Saharan Africa      182870

# %%
plt.figure(figsize=(30,10))
plt.pie(region_rev['Units Sold'],labels = region_rev['Region'], autopct ='%0.1f%%', pctdistance = 0.8)
plt.axis("equal")
plt.show()

# %%
#df.pivot(index = 'Item Type',columns='Year',values='Units Sold').plot(kind='bar')
yearly = df[df['Year'].between(2012,2012)][['Year','Month','Units Sold','Item Type']]
yearly
# Out:
#     Year  Month  Units Sold        Item Type
# 1   2012      8        2804           Cereal
# 7   2012      7        8082       Vegetables
# 15  2012      4        1673          Clothes
# 19  2012      7        5908             Meat
# 29  2012      5        2370        Household
# 30  2012      9        8661        Cosmetics
# 38  2012      4        6708  Office Supplies
# 39  2012      2        3987  Office Supplies
# 42  2012      6        2117           Cereal
# 43  2012     10         171       Vegetables
# 49  2012      1        1266  Office Supplies
# 55  2012      6        3482          Clothes
# 58  2012      1         282        Household
# 66  2012      7        8656    Personal Care
# 78  2012      5        8614        Baby Food
# 80  2012     10        4513        Household
# 81  2012      9        7884          Clothes
# 84  2012      3        6457       Vegetables
# 85  2012      2        6422    Personal Care
# 88  2012      4         522           Fruits
# ...

# %%
yearly = df[df['Year'].between(2010,2010)][['Year','Month','Units Sold','Item Type']]
year_one =  yearly.groupby('Month').sum()['Units Sold'].reset_index()
plt.figure(figsize=(20,5))
plt.bar(year_one['Month'],year_one['Units Sold'],color='maroon')
plt.xticks(year_one['Month'])
plt.ylabel('Units Sold')
plt.xlabel('Months (Year 2010)')
plt.show()

# %%
yearly = df[df['Year'].between(2011,2011)][['Year','Month','Units Sold','Item Type']]
year_one =  yearly.groupby('Month').sum()['Units Sold'].reset_index()
plt.figure(figsize=(20,5))
plt.bar(year_one['Month'],year_one['Units Sold'],color='maroon')
plt.xticks(year_one['Month'])
plt.ylabel('Units Sold')
plt.xlabel('Months (Year 2011)')
plt.show()

# %%
yearly = df[df['Year'].between(2012,2012)][['Year','Month','Units Sold','Item Type']]
year_one =  yearly.groupby('Month').sum()['Units Sold'].reset_index()
plt.figure(figsize=(20,5))
plt.bar(year_one['Month'],year_one['Units Sold'],color='maroon')
plt.xticks(year_one['Month'])
plt.ylabel('Units Sold')
plt.xlabel('Months (Year 2012)')
plt.show()

# %%
yearly = df[df['Year'].between(2013,2013)][['Year','Month','Units Sold','Item Type']]
year_one =  yearly.groupby('Month').sum()['Units Sold'].reset_index()
plt.figure(figsize=(20,5))
plt.bar(year_one['Month'],year_one['Units Sold'],color='maroon')
plt.xticks(year_one['Month'])
plt.ylabel('Units Sold')
plt.xlabel('Months (Year 2013)')
plt.show()

# %%
yearly = df[df['Year'].between(2014,2014)][['Year','Month','Units Sold','Item Type']]
year_one =  yearly.groupby('Month').sum()['Units Sold'].reset_index()
plt.figure(figsize=(20,5))
plt.bar(year_one['Month'],year_one['Units Sold'],color='maroon')
plt.xticks(year_one['Month'])
plt.ylabel('Units Sold')
plt.xlabel('Months (Year 2014)')
plt.show()

# %%
yearly = df[df['Year'].between(2015,2015)][['Year','Month','Units Sold','Item Type']]
year_one =  yearly.groupby('Month').sum()['Units Sold'].reset_index()
plt.figure(figsize=(20,5))
plt.bar(year_one['Month'],year_one['Units Sold'],color='maroon')
plt.xticks(year_one['Month'])
plt.ylabel('Units Sold')
plt.xlabel('Months (Year 2015)')
plt.show()

# %%
yearly = df[df['Year'].between(2016,2016)][['Year','Month','Units Sold','Item Type']]
year_one =  yearly.groupby('Month').sum()['Units Sold'].reset_index()
plt.figure(figsize=(20,5))
plt.bar(year_one['Month'],year_one['Units Sold'],color='maroon')
plt.xticks(year_one['Month'])
plt.ylabel('Units Sold')
plt.xlabel('Months (Year 2016)')
plt.show()

# %%
yearly = df[df['Year'].between(2017,2017)][['Year','Month','Units Sold','Item Type']]
year_one =  yearly.groupby('Month').sum()['Units Sold'].reset_index()
plt.figure(figsize=(20,5))
plt.bar(year_one['Month'],year_one['Units Sold'],color='maroon')
plt.xticks(year_one['Month'])
plt.ylabel('Units Sold')
plt.xlabel('Months (Year 2017)')
plt.show()

# %%
#xpos = np.arange(len(df['Total Cost']))
#plt.bar(xpos-0.2,df['Total Cost'], width = 0.4, label ="Total Cost")

# %%
#plt.bar(xpos-0.2, df['Total Cost'], width = 0.4, label ="TotalCost")
#plt.bar(xpos+0.2, df['Total Profit'], width = 0.4, label ="TotalProfit")
#plt.xticks(xpos,df['Total Profit'])

# %%
pro =  df.groupby('Item Type').sum()[['Total Cost','Total Profit']].sort_values(ascending=False,by=['Total Profit'])
pro
# Out:
#                   Total Cost  Total Profit
# Item Type
# Cosmetics        22045460.94   14556048.66
# Household        22477106.58    7412605.71
# Office Supplies  24655796.32    5929583.75
# Clothes           2553958.40    5233334.40
# Baby Food         6463683.90    3886643.70
# Cereal            3030455.47    2292443.43
# Vegetables        1823237.43    1265819.63
# Personal Care     2760282.36    1220622.48
# Beverages         1802747.32     888047.28
# Snacks            1328789.28     751944.18
# Meat              3893065.75     610610.00
# Fruits             345986.16     120495.18

# %%
df.groupby('Item Type').sum()[['Total Profit', 'Total Cost']].plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Item Type'>

# %%
df.groupby('Item Type').sum()[['Unit Cost', 'Unit Price']].plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Item Type'>
